# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities=[]

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import API keys from config.py file (one level up)
import sys
sys.path.insert(0, '../')  # Path goes here

from config import weather_api_key, g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a8a6343d9724072f19e4ad863aa1d635

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a8a6343d9724072f19e4ad863aa1d635&q=Boston

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Date": city_date})

# # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | altar
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | fortuna
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | srednekolymsk
# Processing Record 9 of Set 1 | kisangani
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | boende
# Processing Record 15 of Set 1 | bara
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | bima
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | ormara
# Processing Record 22 of Set 1 | erie
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | matara
# Processing Record 27 of Set 1 | yongchang
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | muzaffarabad
# Processing Record 30 of Set 1 | corrientes
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | ponta do sol
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | puliyur
# Processing Record 36 of Set 1 | sault sainte marie
# Processing Record 37 of Set 1 | garchitorena
# Processing Record 38 of Set 1 | birao
# Processing Record 39 of Set 1 | bjornevatn
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | sao felix do xingu
# Processing Record 44 of Set 1 | impfondo
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | guangyuan
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | great yarmouth
# Processing Record 2 of Set 2 | deer lake
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | marsh harbour
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | zamora
# Processing Record 7 of Set 2 | visegrad
# Processing Record 8 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | leshukonskoye
# Processing Record 13 of Set 2 | olafsvik
# Processing Record 14 of Set 2 | vanimo
# Processing Record 15 of Set 2 | nishihara
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | san pedro de macoris
# Processing Record 19 of Set 2 | xuddur
# Processing Record 20 of Set 2 | raudeberg
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | ahipara
# Processing Record 23 of Set 2 | yulara
# Processing Record 24 of Set 2 | ramsar
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | sambava
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | codrington
# Processing Record 32 of Set 2 | kaliua
# Processing Record 33 of Set 2 | nanchong
# Processing Record 34 of Set 2 | leh
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | conakry
# Processing Record 37 of Set 2 | kabinda
# Processing Record 38 of Set 2 | kondinskoye
# Processing Record 39 of Set 2 | skjervoy
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | gornopravdinsk
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | jalu
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | millinocket
# Processing Record 1 of Set 3 | moose factory
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | glasgow
# Processing Record 6 of Set 3 | atka
# City not found. Skipping...
# Processing Record 7 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 3 | marsaxlokk
# Processing Record 10 of Set 3 | burnie
# Processing Record 11 of Set 3 | elizabeth city
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | linqiong
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | buin
# Processing Record 18 of Set 3 | dunedin
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | mabaruma
# Processing Record 22 of Set 3 | kousseri
# Processing Record 23 of Set 3 | bobrovka
# Processing Record 24 of Set 3 | ust-omchug
# Processing Record 25 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | pangnirtung
# Processing Record 28 of Set 3 | plettenberg bay
# Processing Record 29 of Set 3 | storforshei
# Processing Record 30 of Set 3 | lae
# Processing Record 31 of Set 3 | yanam
# Processing Record 32 of Set 3 | quelimane
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | el jicaro
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | boda
# Processing Record 39 of Set 3 | coahuayana
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | ulladulla
# Processing Record 43 of Set 3 | isagarh
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | seoul
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | prince rupert
# Processing Record 48 of Set 3 | hamina
# Processing Record 49 of Set 3 | solwezi
# Processing Record 50 of Set 3 | komsomolskiy
# Processing Record 1 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 4 | lere
# Processing Record 3 of Set 4 | constitucion
# Processing Record 4 of Set 4 | ponta delgada
# Processing Record 5 of Set 4 | anshun
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | ribeirao branco
# Processing Record 8 of Set 4 | asfi
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | dunkwa
# Processing Record 11 of Set 4 | calvia
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | barcelos
# Processing Record 14 of Set 4 | pedernales
# Processing Record 15 of Set 4 | samarai
# Processing Record 16 of Set 4 | ambovombe
# Processing Record 17 of Set 4 | kavaratti
# Processing Record 18 of Set 4 | salalah
# Processing Record 19 of Set 4 | santa rosa
# Processing Record 20 of Set 4 | teguldet
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | bathsheba
# Processing Record 23 of Set 4 | panguna
# Processing Record 24 of Set 4 | mana
# Processing Record 25 of Set 4 | walvis bay
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | oksfjord
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | zile
# Processing Record 30 of Set 4 | pozhva
# Processing Record 31 of Set 4 | gambela
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | bloemhof
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 39 of Set 4 | tottori
# Processing Record 40 of Set 4 | tromso
# Processing Record 41 of Set 4 | hobart
# Processing Record 42 of Set 4 | assiniboia
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | passo de camaragibe
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | mezen
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | diapaga
# Processing Record 1 of Set 5 | bluff
# Processing Record 2 of Set 5 | upernavik
# Processing Record 3 of Set 5 | caxito
# Processing Record 4 of Set 5 | teya
# Processing Record 5 of Set 5 | tame
# Processing Record 6 of Set 5 | malinovka
# Processing Record 7 of Set 5 | russellville
# Processing Record 8 of Set 5 | waingapu
# Processing Record 9 of Set 5 | melo
# Processing Record 10 of Set 5 | puerto ayora
# Processing Record 11 of Set 5 | mahibadhoo
# Processing Record 12 of Set 5 | butaritari
# Processing Record 13 of Set 5 | khandyga
# Processing Record 14 of Set 5 | esna
# Processing Record 15 of Set 5 | berdigestyakh
# Processing Record 16 of Set 5 | lengshuijiang
# Processing Record 17 of Set 5 | bonfim
# Processing Record 18 of Set 5 | sept-iles
# Processing Record 19 of Set 5 | cairns
# Processing Record 20 of Set 5 | bria
# Processing Record 21 of Set 5 | kargopol
# Processing Record 22 of Set 5 | erenhot
# Processing Record 23 of Set 5 | pauini
# Processing Record 24 of Set 5 | ribeira grande
# Processing Record 25 of Set 5 | esfarayen
# Processing Record 26 of Set 5 | chara
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | airai
# Processing Record 29 of Set 5 | oliveira dos brejinhos
# Processing Record 30 of Set 5 | araouane
# Processing Record 31 of Set 5 | sorong
# Processing Record 32 of Set 5 | harer
# Processing Record 33 of Set 5 | hayesville
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | bentong
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | fomboni
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | dodge city
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | la crosse
# Processing Record 44 of Set 5 | port hardy
# Processing Record 45 of Set 5 | tortoli
# Processing Record 46 of Set 5 | yar-sale
# Processing Record 47 of Set 5 | santa marinella
# Processing Record 48 of Set 5 | norman wells
# Processing Record 49 of Set 5 | bhavani
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | san juan
# Processing Record 3 of Set 6 | acapulco
# Processing Record 4 of Set 6 | erzin
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | channel-port aux basques
# Processing Record 7 of Set 6 | am timan
# Processing Record 8 of Set 6 | opuwo
# Processing Record 9 of Set 6 | altay
# Processing Record 10 of Set 6 | coquimbo
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | nouadhibou
# Processing Record 13 of Set 6 | kahului
# Processing Record 14 of Set 6 | grieskirchen
# Processing Record 15 of Set 6 | butembo
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | mnogovershinnyy
# Processing Record 18 of Set 6 | thinadhoo
# Processing Record 19 of Set 6 | bamiantong
# Processing Record 20 of Set 6 | waipawa
# Processing Record 21 of Set 6 | port alberni
# Processing Record 22 of Set 6 | acajutla
# Processing Record 23 of Set 6 | whitehorse
# Processing Record 24 of Set 6 | kloulklubed
# Processing Record 25 of Set 6 | dudinka
# Processing Record 26 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | pabna
# Processing Record 29 of Set 6 | melissourgoi
# City not found. Skipping...
# Processing Record 30 of Set 6 | teguise
# Processing Record 31 of Set 6 | argostolion
# Processing Record 32 of Set 6 | novobirilyussy
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | viking
# Processing Record 35 of Set 6 | uyemskiy
# Processing Record 36 of Set 6 | nefteabad
# City not found. Skipping...
# Processing Record 37 of Set 6 | davila
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | alyangula
# Processing Record 40 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 6 | hackettstown
# Processing Record 42 of Set 6 | nemuro
# Processing Record 43 of Set 6 | bendigo
# Processing Record 44 of Set 6 | santa cruz
# Processing Record 45 of Set 6 | noumea
# Processing Record 46 of Set 6 | vredendal
# Processing Record 47 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 6 | penzance
# Processing Record 49 of Set 6 | grindavik
# Processing Record 50 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 7 | shimanovsk
# Processing Record 2 of Set 7 | menidion
# City not found. Skipping...
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | soyo
# Processing Record 5 of Set 7 | gorin
# Processing Record 6 of Set 7 | talcahuano
# Processing Record 7 of Set 7 | karuri
# Processing Record 8 of Set 7 | tual
# Processing Record 9 of Set 7 | moranbah
# Processing Record 10 of Set 7 | santa maria
# Processing Record 11 of Set 7 | kotka
# Processing Record 12 of Set 7 | ulaanbaatar
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | yara
# Processing Record 15 of Set 7 | uyuni
# Processing Record 16 of Set 7 | burica
# City not found. Skipping...
# Processing Record 17 of Set 7 | ouadda
# Processing Record 18 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 7 | caravelas
# Processing Record 20 of Set 7 | ambon
# Processing Record 21 of Set 7 | alugan
# Processing Record 22 of Set 7 | bang lamung
# Processing Record 23 of Set 7 | vilyuysk
# Processing Record 24 of Set 7 | nianzishan
# Processing Record 25 of Set 7 | la palma
# Processing Record 26 of Set 7 | borzya
# Processing Record 27 of Set 7 | ketchikan
# Processing Record 28 of Set 7 | denpasar
# Processing Record 29 of Set 7 | moratuwa
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | latung
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | palmer
# Processing Record 35 of Set 7 | vostok
# Processing Record 36 of Set 7 | topolobampo
# Processing Record 37 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 7 | sumbe
# Processing Record 39 of Set 7 | garowe
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | poya
# Processing Record 42 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | chapais
# Processing Record 46 of Set 7 | tabuk
# Processing Record 47 of Set 7 | bandarbeyla
# Processing Record 48 of Set 7 | la trinidad
# Processing Record 49 of Set 7 | marion
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | langsa
# Processing Record 2 of Set 8 | sal rei
# Processing Record 3 of Set 8 | sisimiut
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | mkushi
# Processing Record 7 of Set 8 | proletariy
# Processing Record 8 of Set 8 | west wendover
# Processing Record 9 of Set 8 | caibarien
# Processing Record 10 of Set 8 | eyl
# Processing Record 11 of Set 8 | bereda
# Processing Record 12 of Set 8 | puerto madero
# Processing Record 13 of Set 8 | machali
# Processing Record 14 of Set 8 | kiama
# Processing Record 15 of Set 8 | porto murtinho
# Processing Record 16 of Set 8 | xudat
# Processing Record 17 of Set 8 | partizanskoye
# Processing Record 18 of Set 8 | shahreza
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | hobyo
# Processing Record 21 of Set 8 | saint-georges
# Processing Record 22 of Set 8 | gilgit
# Processing Record 23 of Set 8 | batagay
# Processing Record 24 of Set 8 | oistins
# Processing Record 25 of Set 8 | nanortalik
# Processing Record 26 of Set 8 | port augusta
# Processing Record 27 of Set 8 | mareeba
# Processing Record 28 of Set 8 | san andres
# Processing Record 29 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | olinda
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | semey
# Processing Record 34 of Set 8 | ambilobe
# Processing Record 35 of Set 8 | lithakia
# Processing Record 36 of Set 8 | conceicao do araguaia
# Processing Record 37 of Set 8 | bubaque
# Processing Record 38 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 8 | lumeje
# Processing Record 41 of Set 8 | blagoyevo
# Processing Record 42 of Set 8 | san buenaventura
# Processing Record 43 of Set 8 | makhachkala
# Processing Record 44 of Set 8 | tiruvannamalai
# Processing Record 45 of Set 8 | shellbrook
# Processing Record 46 of Set 8 | araguacu
# Processing Record 47 of Set 8 | bemidji
# Processing Record 48 of Set 8 | sumenep
# Processing Record 49 of Set 8 | belaya gora
# Processing Record 50 of Set 8 | jinchang
# Processing Record 1 of Set 9 | balsas
# Processing Record 2 of Set 9 | mincivan
# Processing Record 3 of Set 9 | aleksandrov gay
# Processing Record 4 of Set 9 | xiangfan
# Processing Record 5 of Set 9 | quatre cocos
# Processing Record 6 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 9 | coihaique
# Processing Record 8 of Set 9 | celestun
# Processing Record 9 of Set 9 | krasnogorsk
# Processing Record 10 of Set 9 | pangai
# Processing Record 11 of Set 9 | honiton
# Processing Record 12 of Set 9 | amga
# Processing Record 13 of Set 9 | roma
# Processing Record 14 of Set 9 | turgutlu
# Processing Record 15 of Set 9 | boa vista
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | vershino-darasunskiy
# Processing Record 18 of Set 9 | labuhan
# Processing Record 19 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 9 | poli
# Processing Record 21 of Set 9 | goldap
# Processing Record 22 of Set 9 | honiara
# Processing Record 23 of Set 9 | severo-kurilsk
# Processing Record 24 of Set 9 | shenjiamen
# Processing Record 25 of Set 9 | sande
# Processing Record 26 of Set 9 | watrous
# Processing Record 27 of Set 9 | santo augusto
# Processing Record 28 of Set 9 | sioux lookout
# Processing Record 29 of Set 9 | sola
# Processing Record 30 of Set 9 | high level
# Processing Record 31 of Set 9 | pampa
# Processing Record 32 of Set 9 | aklavik
# Processing Record 33 of Set 9 | oranjemund
# Processing Record 34 of Set 9 | necochea
# Processing Record 35 of Set 9 | kiunga
# Processing Record 36 of Set 9 | alice springs
# Processing Record 37 of Set 9 | gimli
# Processing Record 38 of Set 9 | port keats
# Processing Record 39 of Set 9 | houston
# Processing Record 40 of Set 9 | yaan
# Processing Record 41 of Set 9 | puerto del rosario
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | manokwari
# Processing Record 44 of Set 9 | sayat
# Processing Record 45 of Set 9 | birnin kebbi
# Processing Record 46 of Set 9 | eureka
# Processing Record 47 of Set 9 | sheltozero
# Processing Record 48 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 9 | morro bay
# Processing Record 50 of Set 9 | dawei
# Processing Record 1 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 10 | husavik
# Processing Record 3 of Set 10 | homer
# Processing Record 4 of Set 10 | inirida
# Processing Record 5 of Set 10 | marawi
# Processing Record 6 of Set 10 | granadilla de abona
# Processing Record 7 of Set 10 | mushie
# Processing Record 8 of Set 10 | panaba
# Processing Record 9 of Set 10 | kimbe
# Processing Record 10 of Set 10 | nuuk
# Processing Record 11 of Set 10 | dumas
# Processing Record 12 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 13 of Set 10 | maraba
# Processing Record 14 of Set 10 | launceston
# Processing Record 15 of Set 10 | mehran
# Processing Record 16 of Set 10 | takahashi
# Processing Record 17 of Set 10 | hofn
# Processing Record 18 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 19 of Set 10 | ancud
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | duki
# Processing Record 22 of Set 10 | atar
# Processing Record 23 of Set 10 | tecpan
# Processing Record 24 of Set 10 | bitung
# Processing Record 25 of Set 10 | provideniya
# Processing Record 26 of Set 10 | dubovyy umet
# Processing Record 27 of Set 10 | miandrivazo
# Processing Record 28 of Set 10 | shakawe
# Processing Record 29 of Set 10 | omsukchan
# Processing Record 30 of Set 10 | lorengau
# Processing Record 31 of Set 10 | margate
# Processing Record 32 of Set 10 | nuevo progreso
# Processing Record 33 of Set 10 | hamilton
# Processing Record 34 of Set 10 | pachora
# Processing Record 35 of Set 10 | ziro
# Processing Record 36 of Set 10 | alta floresta
# Processing Record 37 of Set 10 | kushima
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | mochudi
# Processing Record 40 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 10 | lyubech
# Processing Record 42 of Set 10 | bandar-e lengeh
# Processing Record 43 of Set 10 | sitka
# Processing Record 44 of Set 10 | kulhudhuffushi
# Processing Record 45 of Set 10 | finschhafen
# Processing Record 46 of Set 10 | esil
# Processing Record 47 of Set 10 | lebyazhye
# Processing Record 48 of Set 10 | sand springs
# Processing Record 49 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 50 of Set 10 | rio grande
# Processing Record 1 of Set 11 | copiapo
# Processing Record 2 of Set 11 | tucuman
# Processing Record 3 of Set 11 | zhongshu
# Processing Record 4 of Set 11 | kerema
# Processing Record 5 of Set 11 | fairbanks
# Processing Record 6 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 11 | sakakah
# Processing Record 8 of Set 11 | san antero
# Processing Record 9 of Set 11 | afsin
# Processing Record 10 of Set 11 | sinnamary
# Processing Record 11 of Set 11 | lensk
# Processing Record 12 of Set 11 | lages
# Processing Record 13 of Set 11 | borken
# Processing Record 14 of Set 11 | sabha
# Processing Record 15 of Set 11 | rangapara
# Processing Record 16 of Set 11 | winnemucca
# Processing Record 17 of Set 11 | coron
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 11 | paita
# Processing Record 21 of Set 11 | termiz
# Processing Record 22 of Set 11 | ostrovnoy
# Processing Record 23 of Set 11 | bo phloi
# Processing Record 24 of Set 11 | acarau
# Processing Record 25 of Set 11 | urambo
# Processing Record 26 of Set 11 | ocos
# Processing Record 27 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 11 | bossangoa
# Processing Record 29 of Set 11 | lokosovo
# Processing Record 30 of Set 11 | seymchan
# Processing Record 31 of Set 11 | chandbali
# Processing Record 32 of Set 11 | bali
# Processing Record 33 of Set 11 | casalmaggiore
# Processing Record 34 of Set 11 | uthal
# Processing Record 35 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 36 of Set 11 | great falls
# Processing Record 37 of Set 11 | san luis
# Processing Record 38 of Set 11 | trairi
# Processing Record 39 of Set 11 | zhanaozen
# Processing Record 40 of Set 11 | bet shemesh
# Processing Record 41 of Set 11 | severo-yeniseyskiy
# Processing Record 42 of Set 11 | marystown
# Processing Record 43 of Set 11 | klaksvik
# Processing Record 44 of Set 11 | baihar
# Processing Record 45 of Set 11 | maues
# Processing Record 46 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 47 of Set 11 | pasni
# Processing Record 48 of Set 11 | muros
# Processing Record 49 of Set 11 | salta
# Processing Record 50 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 12 | buritizeiro
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | maniitsoq
# Processing Record 4 of Set 12 | tadine
# Processing Record 5 of Set 12 | kanigoro
# Processing Record 6 of Set 12 | rocha
# Processing Record 7 of Set 12 | baruun-urt
# Processing Record 8 of Set 12 | fort-shevchenko
# Processing Record 9 of Set 12 | cervo
# Processing Record 10 of Set 12 | san quintin
# Processing Record 11 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 12 | bandiagara
# Processing Record 13 of Set 12 | manjacaze
# Processing Record 14 of Set 12 | porto nacional
# Processing Record 15 of Set 12 | parksville
# Processing Record 16 of Set 12 | onokhoy
# Processing Record 17 of Set 12 | englewood
# Processing Record 18 of Set 12 | uaua
# Processing Record 19 of Set 12 | goderich
# Processing Record 20 of Set 12 | soria
# Processing Record 21 of Set 12 | kharp
# Processing Record 22 of Set 12 | liwale
# Processing Record 23 of Set 12 | flinders
# Processing Record 24 of Set 12 | roebourne
# Processing Record 25 of Set 12 | loksa
# Processing Record 26 of Set 12 | balykshi
# Processing Record 27 of Set 12 | taoudenni
# Processing Record 28 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 12 | hoshcha
# Processing Record 30 of Set 12 | lewistown
# Processing Record 31 of Set 12 | gat
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | yarada
# Processing Record 34 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 12 | kedrovyy
# Processing Record 36 of Set 12 | poronaysk
# Processing Record 37 of Set 12 | tautira
# Processing Record 38 of Set 12 | hokitika
# Processing Record 39 of Set 12 | sistranda
# Processing Record 40 of Set 12 | saint-francois
# Processing Record 41 of Set 12 | northam
# Processing Record 42 of Set 12 | tomatlan
# Processing Record 43 of Set 12 | trinidad
# Processing Record 44 of Set 12 | sovetskaya gavan
# Processing Record 45 of Set 12 | mirpur bathoro
# City not found. Skipping...
# Processing Record 46 of Set 12 | brigantine
# Processing Record 47 of Set 12 | goba
# Processing Record 48 of Set 12 | saint anthony
# Processing Record 49 of Set 12 | sidi bu zayd
# City not found. Skipping...
# Processing Record 50 of Set 12 | juneau
# Processing Record 1 of Set 13 | williams lake
# Processing Record 2 of Set 13 | ferme-neuve
# Processing Record 3 of Set 13 | bodden town
# Processing Record 4 of Set 13 | ballinrobe
# Processing Record 5 of Set 13 | urucara
# Processing Record 6 of Set 13 | rancho palos verdes
# Processing Record 7 of Set 13 | mitsamiouli
# Processing Record 8 of Set 13 | merano
# Processing Record 9 of Set 13 | san vicente
# Processing Record 10 of Set 13 | miraflores
# Processing Record 11 of Set 13 | gazimurskiy zavod
# Processing Record 12 of Set 13 | abu samrah
# Processing Record 13 of Set 13 | charters towers
# Processing Record 14 of Set 13 | babu
# Processing Record 15 of Set 13 | kurtamysh
# Processing Record 16 of Set 13 | pacific grove
# Processing Record 17 of Set 13 | nara
# Processing Record 18 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 19 of Set 13 | takoradi
# Processing Record 20 of Set 13 | jiangyou
# Processing Record 21 of Set 13 | saquena
# Processing Record 22 of Set 13 | llangefni
# Processing Record 23 of Set 13 | trapani
# Processing Record 24 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 13 | deputatskiy
# Processing Record 26 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 13 | muskogee
# Processing Record 28 of Set 13 | lamar
# Processing Record 29 of Set 13 | henties bay
# Processing Record 30 of Set 13 | kirando
# Processing Record 31 of Set 13 | mayahi
# Processing Record 32 of Set 13 | takaka
# Processing Record 33 of Set 13 | guadalupe
# Processing Record 34 of Set 13 | mabini
# Processing Record 35 of Set 13 | weyburn
# Processing Record 36 of Set 13 | te anau
# Processing Record 37 of Set 13 | arman
# Processing Record 38 of Set 13 | birin
# Processing Record 39 of Set 13 | peniche
# Processing Record 40 of Set 13 | byron bay
# Processing Record 41 of Set 13 | hoa binh
# Processing Record 42 of Set 13 | dalby
# Processing Record 43 of Set 13 | nizhnevartovsk
# Processing Record 44 of Set 13 | dharchula
# Processing Record 45 of Set 13 | antalaha
# Processing Record 46 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 13 | aktash
# Processing Record 48 of Set 13 | portland
# Processing Record 49 of Set 13 | kinablangan
# Processing Record 50 of Set 13 | ossora
# Processing Record 1 of Set 14 | presidente medici
# Processing Record 2 of Set 14 | vila franca do campo
# Processing Record 3 of Set 14 | manacor
# Processing Record 4 of Set 14 | macusani
# Processing Record 5 of Set 14 | kaiyuan
# Processing Record 6 of Set 14 | conde
# Processing Record 7 of Set 14 | vaitape
# Processing Record 8 of Set 14 | nador
# Processing Record 9 of Set 14 | lima duarte
# Processing Record 10 of Set 14 | kudahuvadhoo
# Processing Record 11 of Set 14 | huanren
# Processing Record 12 of Set 14 | eregli
# Processing Record 13 of Set 14 | nagorsk
# Processing Record 14 of Set 14 | okha
# Processing Record 15 of Set 14 | bokovskaya
# Processing Record 16 of Set 14 | itoman
# Processing Record 17 of Set 14 | australind
# Processing Record 18 of Set 14 | karpinsk
# Processing Record 19 of Set 14 | rawah
# Processing Record 20 of Set 14 | xianyang
# Processing Record 21 of Set 14 | tamandare
# Processing Record 22 of Set 14 | uspenka
# Processing Record 23 of Set 14 | venice
# Processing Record 24 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 14 | hare bay
# Processing Record 26 of Set 14 | mayskiy
# Processing Record 27 of Set 14 | knysna
# Processing Record 28 of Set 14 | lingao
# Processing Record 29 of Set 14 | bosaso
# Processing Record 30 of Set 14 | moron
# Processing Record 31 of Set 14 | ust-tsilma
# Processing Record 32 of Set 14 | andenes
# Processing Record 33 of Set 14 | guiren
# Processing Record 34 of Set 14 | qom
# Processing Record 35 of Set 14 | begichevskiy
# Processing Record 36 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 37 of Set 14 | buseresere
# Processing Record 38 of Set 14 | mantua
# Processing Record 39 of Set 14 | shuya
# Processing Record 40 of Set 14 | chabahar
# Processing Record 41 of Set 14 | balgazyn
# Processing Record 42 of Set 14 | hovd
# Processing Record 43 of Set 14 | kaeo
# Processing Record 44 of Set 14 | lubao
# Processing Record 45 of Set 14 | tessalit
# Processing Record 46 of Set 14 | mikhaylovka
# Processing Record 47 of Set 14 | empalme
# Processing Record 48 of Set 14 | nieuw amsterdam
# Processing Record 49 of Set 14 | ornskoldsvik
# Processing Record 50 of Set 14 | gizo
# Processing Record 1 of Set 15 | blacksburg
# Processing Record 2 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 15 | guiratinga
# Processing Record 4 of Set 15 | bowen
# Processing Record 5 of Set 15 | treinta y tres
# Processing Record 6 of Set 15 | mbandaka
# Processing Record 7 of Set 15 | isilkul
# Processing Record 8 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 15 | smithers
# Processing Record 10 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 15 | auch
# Processing Record 12 of Set 15 | broome
# Processing Record 13 of Set 15 | alappuzha
# Processing Record 14 of Set 15 | nurota
# Processing Record 15 of Set 15 | buttelborn
# Processing Record 16 of Set 15 | berlevag
# Processing Record 17 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 15 | port lincoln
# Processing Record 19 of Set 15 | nortelandia
# Processing Record 20 of Set 15 | marzuq
# Processing Record 21 of Set 15 | parana
# Processing Record 22 of Set 15 | anadyr
# Processing Record 23 of Set 15 | agadez
# Processing Record 24 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 15 | turukhansk
# Processing Record 26 of Set 15 | opportunity
# Processing Record 27 of Set 15 | gurun
# Processing Record 28 of Set 15 | stutterheim
# Processing Record 29 of Set 15 | richards bay
# Processing Record 30 of Set 15 | kalaikunda
# Processing Record 31 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 15 | ca mau
# Processing Record 33 of Set 15 | tongchuan
# Processing Record 34 of Set 15 | san lorenzo
# Processing Record 35 of Set 15 | tateyama
# Processing Record 36 of Set 15 | rio gallegos
# Processing Record 37 of Set 15 | punta alta
# Processing Record 38 of Set 15 | faya
# Processing Record 39 of Set 15 | itarema
# Processing Record 40 of Set 15 | nadbai
# Processing Record 41 of Set 15 | ulaangom
# Processing Record 42 of Set 15 | sadao
# Processing Record 43 of Set 15 | neryungri
# Processing Record 44 of Set 15 | caninde de sao francisco
# Processing Record 45 of Set 15 | asau
# Processing Record 46 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 15 | banda aceh
# Processing Record 48 of Set 15 | pavlovskiy
# Processing Record 49 of Set 15 | la tuque
# Processing Record 50 of Set 15 | padang
# Processing Record 1 of Set 16 | quimperle
# Processing Record 2 of Set 16 | shieli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     42.91        87         100
# 1           Pevek      RU  69.7008  170.3133     32.92        97          79
# 2           Altar      MX  30.7000 -111.8167     91.36        16           0
# 3       Jamestown      US  42.0970  -79.2353     76.95        78         100
# 4         Fortuna      US  40.5982 -124.1573     66.85        63          20
# ..            ...     ...      ...       ...       ...       ...         ...
# 683    Pavlovskiy      RU  57.8424   54.8436     33.76        95          19
# 684      La Tuque      CA  47.4334  -72.7824     65.44        63         100
# 685        Padang      ID  -0.9492  100.3543     76.95        87          34
# 686     Quimperle      FR  47.8667   -3.5500     58.98        82           0
# 687        Shieli      KZ  44.1667   66.7500     73.18        26          42
#
#      Wind Speed       Description                 Date
# 0          4.61   overcast clouds  2022-05-20 20:54:10
# 1          5.48     broken clouds  2022-05-20 20:54:11
# 2         25.86         clear sky  2022-05-20 20:54:11
# 3          8.99   overcast clouds  2022-05-20 20:54:12
# 4         20.71        few clouds  2022-05-20 20:54:12
# ..          ...               ...                  ...
# 683        7.38        few clouds  2022-05-20 21:13:06
# 684       13.20   overcast clouds  2022-05-20 21:13:07
# 685        3.06  scattered clouds  2022-05-20 21:13:07
# 686        9.22         clear sky  2022-05-20 21:14:07
# 687        6.15  scattered clouds  2022-05-20 21:14:08
#
# [688 rows x 10 columns]

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
